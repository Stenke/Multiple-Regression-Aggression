# %% [markdown]
# # Exploring Your Data - Lab
#
# ## Introduction
#
# In this lab, you'll perform an EDA task, using your skills with statistics and data visualizations. You'll continue using the Lego dataset that you've acquired and cleaned in the previous labs.
#
# ## Objectives
# You will be able to:
#
# * Examine the descriptive statistics of our data set
# * Create visualizations to better understand the distributions of variables in a dataset
#
# ## Data Exploration
#
# At this point, you've already done a modest amount of EDA between investigating the initial dataset to further exploring individual features while cleaning things up in preparation for modeling. During this process, you've become more familiar with the particular idiosyncrasies of the dataset. This gives you an opportunity to uncover difficulties and potential pitfalls in working with the dataset as well as potential avenues for feature engineering that could improve the predictive performance of your model down the line. Remember that this is also not a linear process; after building an initial model, you might go back and continue to mine the dataset for potential inroads to create additional features and improve the model's performance if the initial results did not satisfy your needs and expectations. Here, you'll continue this process, investigating the distributions of some of the various features and their relationship to the target variable: `list_price`.

# %% [markdown]
# In the cells below:
#
# * Import `pandas` and set the standard alias.
# * Import `numpy` and set the standard alias.
# * Import `matplotlib.pyplot` and set the standard alias.
# * Import `seaborn` and set the alias `sns` (this is the standard alias for seaborn).
# * Use the ipython magic command to set all matplotlib visualizations to display inline in the notebook.
# * Load the dataset stored in the `'Lego_data_cleaned.csv'` file into a DataFrame, `df`.
# * Inspect the head of the DataFrame to ensure everything loaded correctly.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Import libraries and load Lego_data_merged.csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

leggo = pd.read_csv('Lego_data_cleaned.csv')

# %% [markdown]
# - Describe the dataset using 5-point statistics.

# %%
leggo.head()
# Out:
#    prod_id  ages                        set_name    theme_name country  \
# 0    75823  6-12           Bird Island Egg Heist  Angry Birds™      US
# 1    75822  6-12              Piggy Plane Attack  Angry Birds™      US
# 2    75821  6-12                Piggy Car Escape  Angry Birds™      US
# 3    21030   12+  United States Capitol Building  Architecture      US
# 4    21035   12+   Solomon R. Guggenheim Museum®  Architecture      US
#
#    list_price review_difficulty  norm_piece_count  norm_num_reviews  \
# 0       29.99           Average         -0.273020         -0.398512
# 1       19.99              Easy         -0.404154         -0.398512
# 2       12.99              Easy         -0.517242         -0.147162
# 3       99.99           Average          0.635296          0.187972
# 4       79.99       Challenging          0.288812         -0.063378
#
#    norm_play_star_rating  norm_star_rating  norm_val_star_rating
# 0              -0.655279         -0.045687             -0.365010
# 1              -0.655279          0.990651             -0.365010
# 2              -0.132473         -0.460222             -0.204063
# 3              -1.352353          0.161581              0.117830
# 4              -2.049427          0.161581             -0.204063

# %%
# Your code here
leggo.describe()
# Out:
#             prod_id    list_price  norm_piece_count  norm_num_reviews  \
# count  1.087000e+04  10870.000000      1.087000e+04      1.087000e+04
# mean   6.181634e+04     67.309137      1.154959e-16      3.087316e-16
# std    1.736390e+05     94.669414      1.000000e+00      1.000000e+00
# min    6.300000e+02      2.272400     -6.050659e-01     -4.264402e-01
# 25%    2.112300e+04     21.899000     -4.895715e-01     -3.705846e-01
# 50%    4.207350e+04     36.587800     -3.379852e-01     -2.868011e-01
# 75%    7.124800e+04     73.187800      6.263593e-02     -1.192341e-01
# max    2.000431e+06   1104.870000      8.466055e+00      9.795146e+00
#
#        norm_play_star_rating  norm_star_rating  norm_val_star_rating
# count           1.087000e+04      1.087000e+04          1.087000e+04
# mean            3.548158e-14      2.524533e-13         -1.584896e-13
# std             1.000000e+00      1.000000e+00          1.000000e+00
# min            -5.883334e+00     -5.641909e+00         -5.193413e+00
# 25%            -4.810100e-01     -4.602216e-01         -3.650101e-01
# 50%             2.160641e-01      1.615809e-01          1.178302e-01
# 75%             5.646012e-01      7.833834e-01          6.006705e-01
# max             1.087407e+00      9.906510e-01          1.244458e+00

# %%
leggo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10870 entries, 0 to 10869
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   prod_id                10870 non-null  int64
#  1   ages                   10870 non-null  object
#  2   set_name               10870 non-null  object
#  3   theme_name             10870 non-null  object
#  4   country                10870 non-null  object
#  5   list_price             10870 non-null  float64
#  6   review_difficulty      10870 non-null  object
#  7   norm_piece_count       10870 non-null  float64
#  8   norm_num_reviews       10870 non-null  float64
#  9   norm_play_star_rating  10870 non-null  float64
#  10  norm_star_rating       10870 non-null  float64
#  11  norm_val_star_rating   10870 non-null  float64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 1019.2+ KB

# %% [markdown]
# - Use pandas to plot histograms for all the numeric variables in the dataset.

# %% [markdown]
# Note how skewed most of these distributions are. While linear regression does not assume that each of the individual predictors are normally distributed, it does assume a linear relationship between the predictors and the target variable (`list_price` in this case). To further investigate if this assumption holds true, you can plot some single variable regression plots of each feature against the target variable using `seaborn`.
#
# ## Check for Linearity
#
# Recall that one assumption in linear regression is that the target variable is linearly related to the input features. As shown in the previous lesson, you can use the `sns.jointplot()` function to investigate whether this relation holds true for the various predictors on hand.

# %%
# The only real relationship that has correlation with list_price is the piece_counts

# %%
feats = ['norm_piece_count', 'norm_play_star_rating', 'norm_star_rating', 'norm_val_star_rating']

# %%
leggo_feats = leggo[feats]

# %%
g = sns.PairGrid(leggo, y_vars=['list_price'], x_vars=['norm_piece_count', 'norm_play_star_rating', 'norm_star_rating', 'norm_val_star_rating'])
g.map(sns.regplot);
# g.map_diag(sns.kdeplot)
# g.map_offdiag(sns.regplot);

# %%
sns.jointplot('norm_piece_count','list_price', data=leggo, kind='reg');
sns.jointplot('norm_play_star_rating','list_price', data=leggo, kind='reg');
sns.jointplot('norm_star_rating','list_price', data=leggo, kind='reg');
sns.jointplot('norm_val_star_rating','list_price', data=leggo, kind='reg');

# %% [markdown]
# ## Checking for Multicollinearity
#
# It's also important to make note of whether your predictive features will result in multicollinearity in the resulting model. While definitive checks for multicollinearity require analyzing the resulting model, predictors with overly high pairwise-correlation (r > .65) are almost certain to produce multicollinearity in a model. With that, take a minute to generate the pairwise (pearson) correlation coefficients of your predictive features and visualize these coefficients as a heatmap.

# %%
# Your code here
leggo[feats].corr()
# Out:
#                        norm_piece_count  norm_play_star_rating  \
# norm_piece_count               1.000000              -0.023281
# norm_play_star_rating         -0.023281               1.000000
# norm_star_rating               0.055481               0.619044
# norm_val_star_rating           0.057313               0.485843
#
#                        norm_star_rating  norm_val_star_rating
# norm_piece_count               0.055481              0.057313
# norm_play_star_rating          0.619044              0.485843
# norm_star_rating               1.000000              0.728203
# norm_val_star_rating           0.728203              1.000000

# %% [markdown]
# ## Log Normalization

# %%
non_normal_feats = feats
for feat in non_normal_feats:
    leggo[feat+'_log'] = leggo[feat].map(lambda x: np.log(x))

# %%
non_normal_feats
# Out:
# ['norm_piece_count',
#  'norm_play_star_rating',
#  'norm_star_rating',
#  'norm_val_star_rating']

# %%
log_list = ['norm_piece_count_log', 'norm_play_star_rating_log', 'norm_star_rating_log', 'norm_val_star_rating_log']

# %%
pd.plotting.scatter_matrix(leggo[log_list], figsize=(10,12));

# %%
g = sns.PairGrid(leggo, y_vars=['list_price'], x_vars=['norm_piece_count_log', 'norm_play_star_rating_log', 'norm_star_rating_log', 'norm_val_star_rating_log'])
g.map(sns.regplot);

# %% [markdown]
# ## Further Resources
#
# Have a look at following resources on how to deal with complex datasets that don't meet our initial expectations:
#
# - [What to Do When Bad Data Thwarts Machine Learning Success](https://towardsdatascience.com/what-to-do-when-bad-data-thwarts-machine-learning-success-fb82249aae8b)
#
# - [Practical advice for analysis of large, complex data sets ](http://www.unofficialgoogledatascience.com/2016/10/practical-advice-for-analysis-of-large.html)
#
# - [Data Cleaning Challenge: Scale and Normalize Data](https://www.kaggle.com/rtatman/data-cleaning-challenge-scale-and-normalize-data)
#
# ## Summary
#
# In this lesson you performed some initial EDA using descriptive statistics and data visualizations to check for regression assumptions. In the upcoming lessons, you'll continue to carry out a standard Data Science process and begin to fit and refine an initial model.
